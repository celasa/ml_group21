# %%
import pandas as pd
import numpy as np

# %%
receivals = pd.read_csv("/home/celinaha/ml_group21/data/kernel/receivals.csv").copy()
purchase_orders = pd.read_csv("/home/celinaha/ml_group21/data/kernel/purchase_orders.csv").copy()

receivals.head(20)
#purchase_orders.head(20)

#import seaborn as sns

#recievals.info() # Info about data frame dimensions, column types, and file size
#recievals.describe() # Generate a summary of statistics for each numerical column of the data frame
#recievals.nunique() # to understand which variable belongs to which datatype

#purchase_orders.info()
#purchase_orders.nunique()
# Out:
#     rm_id  product_id  purchase_order_id  purchase_order_item_no  \
# 0   365.0  91900143.0           208545.0                    10.0
# 1   365.0  91900143.0           208545.0                    10.0
# 2   365.0  91900143.0           208490.0                    10.0
# 3   365.0  91900143.0           208490.0                    10.0
# 4   379.0  91900296.0           210435.0                    20.0
# 5   389.0  91900330.0           208535.0                    30.0
# 6   365.0  91900143.0           208532.0                    10.0
# 7   369.0  91900146.0           208532.0                    30.0
# 8   366.0  91900160.0           208532.0                    20.0
# 9   365.0  91900143.0           208537.0                    10.0
# 10  367.0  91900143.0           208547.0                    10.0
# 11  367.0  91900143.0           208532.0                    10.0
# 12  367.0  91900143.0           208541.0                    10.0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

rm_id_group = receivals.groupby('rm_id')['purchase_order_id'].count()
rm_id_group.plot(kind='bar', figsize=(6,5))
plt.xlabel('rm_id')
plt.ylabel('count')
plt.show()
